# %% [markdown]
# # Gemini Basic Agent
#
# Run a Gemini model through the OpenAI Agents SDK using Gemini's OpenAI-compatible endpoint.

# %% [markdown]
# ## 1. Install dependencies
#
# Run this cell once when starting a new Colab session.

# %%
# %pip install -q openai-agents requests google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 32.3 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Configure Gemini
#
# Add `GEMINI_API_KEY` to the Colab **Secrets** panel before running this cell.

# %%
from google.colab import userdata

GEMINI_API_KEY = userdata.get("GeminiAPI")
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
GEMINI_MODEL_NAME = "gemini-3.8-flash"

if not GEMINI_API_KEY:
    raise ValueError("Add GEMINI_API_KEY to Colab Secrets before running this notebook.")

# %% [markdown]
# ## 3. Define and run the agent

# %%
from agents import Agent, OpenAIChatCompletionsModel, Runner, set_tracing_disabled
from openai import AsyncOpenAI

set_tracing_disabled(disabled=True)

gemini_model = OpenAIChatCompletionsModel(
    model=GEMINI_MODEL_NAME,
    openai_client=AsyncOpenAI(
        base_url=GEMINI_BASE_URL,
        api_key=GEMINI_API_KEY,
    ),
)

agent = Agent(
    name="Learning Assistant",
    instructions="""
You are a helpful, accurate, and beginner-friendly AI assistant.

- Explain things clearly and simply.
- Assume the user may be a beginner.
- Use examples when useful.
- Break complex topics into smaller parts.
- Be concise for simple questions.
- Be detailed when needed.
- Never invent facts.
- If unsure, say so clearly.
""",
    model=gemini_model,
)

result = await Runner.run(
    starting_agent=agent,
    input=(
        "Explain the University of Colombo School of Computing "
        "Master of Business Analytics program."
    ),
)

print(result.final_output)
# Out:
# The **Master of Business Analytics (MBAnalytics)** offered by the **University of Colombo School of Computing (UCSC)** in Sri Lanka is a postgraduate degree designed to bridge the gap between **data analysis** and **business decision-making**.
#
# Here is a clear and simple breakdown of what the program is, what you learn, and who it is for.
#
# ---
#
# ### 1. What is Business Analytics? (A Quick Example)
# Imagine a supermarket chain wants to know which products to stock for the holidays. Instead of guessing, they analyze years of sales data, customer buying habits, and seasonal trends to predict exact demand.
#
# **Business Analytics** is the practice of using data, statistical models, and technology to solve business problems and make smarter decisions.
#
# ---
#
# ### 2. Overview of the UCSC Program
# UCSC is one of the premier higher education institutes for computing in Sri Lanka. This program is tailored to build professionals who understand both the technical side (coding, statistics, machine learning) and the business side (management, strategy, finance).
#
# * **Duration:** Typically **2 years** (divided into 4 semesters).
# * **Delivery Mode:** Usually held on **weekends** or evenings, making it suitable for working professionals.
# * **Qualification Level:** Aligned with the **Sri Lanka Qualifications Framework (SLQF Level 9 or 10)**, depending on whether you complete the coursework-only option or the research dissertation.
#
# ---
#
# ### 3. What Will You Learn? (Core Areas)
# The curriculum generally covers three main pillars:
#
# #### A. Data and Computing Foundations
# * **Programming for Analytics:** Working with tools like Python or R.
# * **Database Management & Big Data:** Handling large sets of data using SQL and modern data storage technologies.
#
# #### B. Mathematics and Modeling
# * **Statistical Methods:** Understanding probability, trends, and data distributions.
# * **Machine Learning & Data Mining:** Teaching computers to recognize patterns and make predictions.
#
# #### C. Business Application & Strategy
# * **Business Intelligence (BI) & Data Visualization:** Using dashboards (like Power BI or Tableau) to present data clearly to executives.
# * **Domain Analytics:** Applying analytics to specific business areas such as marketing, supply chain, finance, and human resources.
# * **Final Project:** Applying what you have learned to solve a real-world business problem or conducting research.
#
# ---
#
# ### 4. Who is This Program For?
# This course is designed for:
# * **IT and Software Professionals** who want to move into data science, business intelligence, or management roles.
# * **Business, Finance, or Marketing Professionals** who want to develop strong quantitative and technical skills.
# * **Graduates** with a background in mathematics, statistics, engineering, or management who want to specialize in analytics.
#
# ---
#
# ### 5. General Entry Requirements
# While specific requirements can vary slightly per intake, applicants generally need:
# 1. A Bachelor’s degree in **Computing, Engineering, Science, Management, or Mathematics** from a recognized university.
#    * *OR* an equivalent professional qualification (e.g., CIMA, BCS, CIM) combined with relevant work experience.
# 2. A good command of **English** (since all lectures and materials are in English).
# 3. Passing an **entrance examination** and/or an **interview** conducted by UCSC.
#
# ---
#
# ### 6. Career Paths After the Degree
# Graduates typically step into roles such as:
# * **Business Analyst / Senior Business Analyst**
# * **Data Analyst / Data Scientist**
# * **Business Intelligence (BI) Consultant**
# * **Analytics Project Manager**
# * **Strategic Operations Manager**
#
# ---
#
# ### Summary & Next Steps
# The UCSC Master of Business Analytics is a blend of **computer science**, **statistics**, and **business management**. It is ideal if you want to help organizations make data-driven decisions.
#
# > **Tip:** Admission cycles, fees, and application deadlines are published on the official **[UCSC Website](https://ucsc.cmb.ac.lk)**. It is best to check their postgraduate section directly for the most up-to-date call for applications.
